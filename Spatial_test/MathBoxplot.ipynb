# %%
import matplotlib.pyplot as plt

gender = ['Female','Female','Female','Female','Female','Male','Female','Male','Male','Male','Female','Male','Male','Male','Male','Female','Female','Male','Female','Female','Male','Female','Female','Female','Female','Female','Female','Female']


percentscore = [72.72727273,88.88888889,55.55555556,70,85.71428571,60,80,50,77.77777778,60,55.55555556,81.81818182,66.66666667,77.77777778,77.77777778,66.66666667,90.90909091,70,80,77.77777778,80,55.55555556,62.5,60,77.77777778,80,66.66666667,70]

data = {'Male':[], 'Female':[]}

for g, ps in zip(gender, percentscore):
    data[g].append(ps)

score_values = [data['Male'],data['Female']]

plt.boxplot(score_values,
            labels=['Male','Female'])
plt.xlabel('Gender')
plt.ylabel('Score (%)')
plt.title('Relationship Between Gender and Score in the Maths Test')

plt.show()
