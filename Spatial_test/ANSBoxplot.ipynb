# %%
import matplotlib.pyplot as plt

gender = ['Male','Female','Male','Female','Male','Female','Female','Male','Male','Female','Male','Female','Female','Female','Female','Female','Female','Male','Female','Female','Female']
percentscore = [98.44,90.62,1.56,95.31,82.81,92.19,96.88,96.88,95.31,82.81,92.19,89.06,89.06,01.56,89.06,0,73.44,95.31,84.38,95.31,89.06,95.31,96.88,79.69,93.75,89.06,92.19,95.31,87.50,92.19]
data = {'Male':[], 'Female':[]}

for g, ps in zip(gender, percentscore):
    data[g].append(ps)

score_values = [data['Male'],data['Female']]

plt.boxplot(score_values,
            labels=['Male','Female'])
plt.xlabel('Gender')
plt.ylabel('Score (%)')
plt.title('Relationship Between Gender and Score in the ANS Task')

plt.show()
